# %%
t = []
t1 = {"a":1,"b":2}
t2 = {"a":3,"b":4}
t.append(t1)
t.append(t2)
print(t["a"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12033/2206616926.py in <module>
#       4 t.append(t1)
#       5 t.append(t2)
# ----> 6 print(t["a"])
#
# TypeError: list indices must be integers or slices, not str
